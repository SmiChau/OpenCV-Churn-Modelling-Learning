# %%
# !pip install opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cv2\__init__.py:181
#     176             if DEBUG: print("Extra Python code for", submodule, "is loaded")
#     178     if DEBUG: print('OpenCV loader: DONE')
# --> 181 bootstrap()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cv2\__init__.py:153, in bootstrap()
#     149 if DEBUG: print("Relink everything from native cv2 module to cv2 package")
#     151 py_module = sys.modules.pop("cv2")
# --> 153 native_module = importlib.import_module("cv2")
#     155 sys.modules["cv2"] = py_module
#     156 setattr(py_module, "_native", native_module)
#
# File C:\Program Files\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ...

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import cv2
#
# ImportError: DLL load failed while importing cv2: The specified module could not be found.
